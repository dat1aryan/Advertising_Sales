# %% [markdown]
# # Understanding the Data
# This project uses an Advertising dataset stored in a CSV file.
# The dataset contains information about advertising budgets spent on different media platforms and the resulting product sales.
#
# Each row in the dataset represents a single observation of advertising expenditure and its corresponding sales outcome.

# %% [markdown]
# # Data analysis and interpretations

# %%
#importing required library
import pandas as pd #importing panda library  for  data analysis
import numpy as np  #importing numpy library  for mathematical operations
import matplotlib.pyplot as plt  # matplotlib work like MATLAB
import seaborn as sns    # importing seaborn library for data visualization

# %%
#loading the data set
df=pd.read_csv(r"C:\Users\panku\Downloads\Aryan\jupyter notebook\advertising\advertising_data.csv")  # reading the data

# %%
df #data set
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %% [markdown]
# # 📊 Dataset Structure
# Number of rows: 200
#
# Number of columns: 4
#
# File format: CSV (Comma-Separated Values)
#
# Data type: Entirely numerical

# %%
df.head(10)
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
# 5    8.7   48.9       75.0    7.2
# 6   57.5   32.8       23.5   11.8
# 7  120.2   19.6       11.6   13.2
# 8    8.6    2.1        1.0    4.8
# 9  199.8    2.6       21.2   15.6

# %%
df.tail(10)
# Out:
#         TV  Radio  Newspaper  Sales
# 190   39.5   41.1        5.8   10.8
# 191   75.5   10.8        6.0   11.9
# 192   17.2    4.1       31.6    5.9
# 193  166.8   42.0        3.6   19.6
# 194  149.7   35.6        6.0   17.3
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
df.shape
# Out:
# (200, 4)

# %%
df.size
# Out:
# 800

# %%
df.describe() #describe functions tells all basic important function of data set like mean,max,count,25%,50%,75% of data.
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.info() #info tells type of data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
missing_values = df.isnull().sum() #counts the total number of nan value present in data set.
missing_values
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# as we can see, there is no null values in this dataset.

# %% [markdown]
# # Box plot to see distribution
# From Box plot we can see the distribution of the data weather it is normally distributed or not.

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=df)
plt.show()

# %% [markdown]
# as we can see , we have two outliers in the newspaper column in the upper bound region.

# %% [markdown]
# # Statistical Approach QQplot to see the distribution

# %%
pip install pingouin
# Out:
# Collecting pingouin
#   Downloading pingouin-0.5.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: matplotlib in c:\users\panku\anaconda3\lib\site-packages (from pingouin) (3.10.6)
# Requirement already satisfied: numpy in c:\users\panku\anaconda3\lib\site-packages (from pingouin) (2.3.5)
# Requirement already satisfied: pandas>=1.5 in c:\users\panku\anaconda3\lib\site-packages (from pingouin) (2.3.3)
# Collecting pandas-flavor (from pingouin)
#   Downloading pandas_flavor-0.8.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: scikit-learn>=1.2 in c:\users\panku\anaconda3\lib\site-packages (from pingouin) (1.7.2)
# Requirement already satisfied: scipy in c:\users\panku\anaconda3\lib\site-packages (from pingouin) (1.16.3)
# Requirement already satisfied: seaborn in c:\users\panku\anaconda3\lib\site-packages (from pingouin) (0.13.2)
# Requirement already satisfied: statsmodels in c:\users\panku\anaconda3\lib\site-packages (from pingouin) (0.14.5)
# Requirement already satisfied: tabulate in c:\users\panku\anaconda3\lib\site-packages (from pingouin) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\panku\anaconda3\lib\site-packages (from pandas>=1.5->pingouin) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\panku\anaconda3\lib\site-packages (from pandas>=1.5->pingouin) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\panku\anaconda3\lib\site-packages (from pandas>=1.5->pingouin) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\panku\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.5->pingouin) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\panku\anaconda3\lib\site-packages (from scikit-learn>=1.2->pingouin) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\panku\anaconda3\lib\site-packages (from scikit-learn>=1.2->pingouin) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\panku\anaconda3\lib\site-packages (from matplotlib->pingouin) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\panku\anaconda3\lib\site-packages (from matplotlib->pingouin) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\panku\anaconda3\lib\site-packages (from matplotlib->pingouin) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\panku\anaconda3\lib\site-packages (from matplotlib->pingouin) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\panku\anaconda3\lib\site-packages (from matplotlib->pingouin) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\panku\anaconda3\lib\site-packages (from matplotlib->pingouin) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\panku\anaconda3\lib\site-packages (from matplotlib->pingouin) (3.2.5)
# Requirement already satisfied: xarray in c:\users\panku\anaconda3\lib\site-packages (from pandas-flavor->pingouin) (2025.10.1)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\panku\anaconda3\lib\site-packages (from statsmodels->pingouin) (1.0.1)
# Downloading pingouin-0.5.5-py3-none-any.whl (204 kB)
# Downloading pandas_flavor-0.8.1-py3-none-any.whl (8.5 kB)
# Installing collected packages: pandas-flavor, pingouin
#
#    ---------------------------------------- 2/2 [pingouin]
#
# Successfully installed pandas-flavor-0.8.1 pingouin-0.5.5
# Note: you may need to restart the kernel to use updated packages.

# %%
# QQ plot for TV
import pingouin as pg 
pg.qqplot(df['TV'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
# QQ plot for Radio
pg.qqplot(df['Radio'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
# QQ plot for Newspaper
pg.qqplot(df['Newspaper'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
# QQ plot for Sales
pg.qqplot(df['Sales'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %% [markdown]
# # The Relationship between Numerical variables using Scatter Plot

# %%
# Looking the categorical columns
df.select_dtypes(include=['number']).columns.tolist()
# Out:
# ['TV', 'Radio', 'Newspaper', 'Sales']

# %%
#scatter plot vs salary and Base_pay
#distribution of salary on the basis of Base_Pay
plt.figure(figsize=(15,10))
plt.xlabel('TV',fontsize=15)
plt.ylabel('Sales',fontsize=15)
plt.title('TV Vs Sales',fontsize=15)

sns.scatterplot(x=df['TV'],y=df['Sales'],color='black')
plt.show()

# %%
#scatter plot vs salary and Base_pay
#distribution of salary on the basis of Base_Pay
plt.figure(figsize=(15,10))
plt.xlabel('Radio',fontsize=15)
plt.ylabel('Sales',fontsize=15)
plt.title('Radio Vs Sales',fontsize=15)

sns.scatterplot(x=df['Radio'],y=df['Sales'],color='black')
plt.show()

# %%
#scatter plot vs salary and Base_pay
#distribution of salary on the basis of Base_Pay
plt.figure(figsize=(15,10))
plt.xlabel('Newspaper',fontsize=15)
plt.ylabel('Sales',fontsize=15)
plt.title('Newspaper Vs Sales',fontsize=15)

sns.scatterplot(x=df['Newspaper'],y=df['Sales'],color='black')
plt.show()

# %% [markdown]
# # Checking Outliers

# %%
plt.figure(figsize=(9,7)) #size of graph
figure=df.boxplot(column="TV")

# %%
plt.figure(figsize=(9,7)) #size of graph
figure=df.boxplot(column="Radio")

# %%
plt.figure(figsize=(9,7)) #size of graph
figure=df.boxplot(column="Newspaper")

# %%
plt.figure(figsize=(9,7)) #size of graph
figure=df.boxplot(column="Sales")

# %% [markdown]
# # Finding out the correlation between variables using spearman

# %%
df_numeric = df.select_dtypes(include='number')
# Spearman rank correlation heatmap

df_numeric.corr(method="spearman")# selecting the method as a sperman
plt.figure(figsize=(20,8))# setting the figuresize

heatmap = sns.heatmap(df_numeric.corr(method = 'spearman').round(3), vmin=-1, 
vmax=1, annot=True) #annot = True means writting the data value in each cell.

font2= {'family':'serif','color':'green','size':20}
plt.title("Spearman Rank Correlation",font2)
plt.show()# displaying heatmap

# %%
# Looking to the percentage of correlation 
df_numeric = df.select_dtypes(include='number')
df_numeric.corr(method='spearman')*100
# Out:
#                    TV       Radio   Newspaper       Sales
# TV         100.000000    5.612339    5.083973   90.099564
# Radio        5.612339  100.000000   31.697949   33.994909
# Newspaper    5.083973   31.697949  100.000000   12.302741
# Sales       90.099564   33.994909   12.302741  100.000000

# %% [markdown]
# # Handling Outliers

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

outliers = ((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).sum()
outliers
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df = df[~((df < (Q1 - 1.5 * IQR)) | 
         (df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %% [markdown]
# # Sanity check whether outliers are removed or not

# %%
sns.boxplot(x=df['TV'])
# Out:
# <Axes: xlabel='TV'>

# %%
sns.boxplot(x=df['Radio'])
# Out:
# <Axes: xlabel='Radio'>

# %%
sns.boxplot(x=df['Newspaper'])
# Out:
# <Axes: xlabel='Newspaper'>

# %%
sns.boxplot(x=df['Sales'])
# Out:
# <Axes: xlabel='Sales'>

# %% [markdown]
# # Model Building

# %% [markdown]
# In Model Buidling we have to prepare the data set for machine learning algorithm. Also we have to prepare the date in such a way that it gives better efficiency. For stability of data set we can drop the highly co-related features in the data set.

# %%
x = df[['TV', 'Radio', 'Newspaper']] 
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [198 rows x 3 columns]

# %%
y = df['Sales']
y
# Out:
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 198, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.3, random_state=0)

# %%
x_train
# Out:
#         TV  Radio  Newspaper
# 141  193.7   35.4       75.6
# 81   239.8    4.1       36.9
# 20   218.4   27.7       53.4
# 161   85.7   35.8       49.3
# 91    28.6    1.5       33.0
# ..     ...    ...        ...
# 68   237.4   27.5       11.0
# 194  149.7   35.6        6.0
# 119   19.4   16.0       22.3
# 48   227.2   15.8       49.9
# 174  222.4    3.4       13.1
#
# [138 rows x 3 columns]

# %%
y_train
# Out:
# 141    19.2
# 81     17.3
# 20     18.0
# 161    13.3
# 91      7.3
#        ...
# 68     18.9
# 194    17.3
# 119     6.6
# 48     19.8
# 174    16.5
# Name: Sales, Length: 138, dtype: float64

# %%
x_test
# Out:
#         TV  Radio  Newspaper
# 19   147.3   23.9       19.1
# 170   50.0   11.6       18.4
# 64   131.1   42.8       28.9
# 177  170.2    7.8       35.2
# 72    26.8   33.0       19.3
# 87   110.7   40.6       63.2
# 5      8.7   48.9       75.0
# 120  141.3   26.8       46.2
# 12    23.8   35.1       65.9
# 152  197.6   23.3       14.2
# 61   261.3   42.7       54.7
# 76    27.5    1.6       20.7
# 165  234.5    3.4       84.8
# 97   184.9   21.0       22.0
# 115   75.1   35.0       52.7
# 7    120.2   19.6       11.6
# 34    95.7    1.4        7.4
# 136   25.6   39.0        9.3
# 38    43.1   26.7       35.1
# 168  215.4   23.6       57.6
# 111  241.7   38.0       23.2
# 145  140.3    1.9        9.0
# 46    89.7    9.9       35.7
# 159  131.7   18.4       34.6
# 140   73.4   17.0       12.9
# 113  209.6   20.6       10.7
# 179  165.6   10.0       17.6
# 185  205.0   45.1       19.6
# 93   250.9   36.5       72.3
# 45   175.1   22.5       31.5
# 17   281.4   39.6       55.8
# 137  273.7   28.9       59.7
# 138   43.0   25.9       20.5
# 98   289.7   42.3       51.2
# 23   228.3   16.9       26.2
# 196   94.2    4.9        8.1
# 128  220.3   49.0        3.2
# 4    180.8   10.8       58.4
# 67   139.3   14.5       10.2
# 125   87.2   11.8       25.9
# 133  219.8   33.5       45.1
# 175  276.9   48.9       41.8
# 27   240.1   16.7       22.9
# 62   239.3   15.5       27.3
# 147  243.2   49.0       44.3
# 84   213.5   43.0       33.8
# 8      8.6    2.1        1.0
# 143  104.6    5.7       34.4
# 75    16.9   43.7       89.4
# 189   18.7   12.1       23.4
# 99   135.2   41.7       45.9
# 56     7.3   28.1       41.4
# 146  240.1    7.3        8.7
# 164  117.2   14.7        5.4
# 25   262.9    3.5       19.5
# 31   112.9   17.4       38.6
# 114   78.2   46.8       34.5
# 41   177.0   33.4       38.7
# 57   136.2   19.2       16.6
# 181  218.5    5.4       27.4

# %%
y_test
# Out:
# 19     14.6
# 170     8.4
# 64     16.0
# 177    16.7
# 72      8.8
# 87     16.0
# 5       7.2
# 120    15.5
# 12      9.2
# 152    16.6
# 61     24.2
# 76      6.9
# 165    16.9
# 97     20.5
# 115    12.6
# 7      13.2
# 34     11.9
# 136     9.5
# 38     10.1
# 168    17.1
# 111    21.8
# 145    10.3
# 46     10.6
# 159    12.9
# 140    10.9
# 113    20.9
# 179    17.6
# 185    22.6
# 93     22.2
# 45     16.1
# 17     24.4
# 137    20.8
# 138     9.6
# 98     25.4
# 23     20.5
# 196    14.0
# 128    24.7
# 4      17.9
# 67     13.4
# 125    10.6
# 133    19.6
# 175    27.0
# 27     20.9
# 62     20.7
# 147    25.4
# 84     21.7
# 8       4.8
# 143    10.4
# 75      8.7
# 189     6.7
# 99     17.2
# 56      5.5
# 146    18.2
# 164    11.9
# 25     17.0
# 31     11.9
# 114    14.6
# 41     17.1
# 57     13.2
# 181    17.2
# Name: Sales, dtype: float64

# %%
# data normalization with sklearn
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
# fit scaler on training data
x_train = sc.fit_transform(x_train)

# transform testing data
x_test = sc.transform(x_test)

# %%
x_train
# Out:
# array([[ 0.55443001,  0.8645325 ,  2.34796104],
#        [ 1.0916911 , -1.25083695,  0.42016829],
#        [ 0.84229007,  0.3441381 ,  1.24209543],
#        [-0.70422939,  0.89156598,  1.03785899],
#        [-1.36968728, -1.42655454,  0.2258946 ],
#        [ 0.61503213,  1.81070414,  1.57086629],
#        [ 0.20247154,  0.95914967, -1.04933781],
#        [ 0.81898156,  1.29030974,  0.55466546],
#        [-1.6051032 ,  0.31034626, -1.31335078],
#        [ 0.45187257,  1.43899385, -1.33327628],
#        [-1.04802987, -1.14270305,  0.06150917],
#        [-0.13783266, -1.19677   , -0.95469166],
#        [-0.76832779, -1.52793007, -0.95967304],
#        [ 0.12205719, -1.35221248, -1.00450542],
#        [ 1.25485065, -0.08839751,  0.0764533 ],
#        [ 1.27349746,  0.29007115, -1.14398397],
#        [ 0.67563424,  0.69557328,  0.87347356],
#        [ 1.19657938,  0.30358789, -0.27722444],
#        [ 0.97165229,  0.65502307,  2.27822177],
#        [ 0.35980397, -0.89940177, -1.09915158],
#        [ 1.09285653,  1.276793  , -0.49640501],
#        [-1.25780644, -1.27787042, -0.73052971],
#        [-1.55032821, -1.50089659, -0.14272727],
#        [-0.50610708,  0.47254711, -0.99952405],
#        [-1.50254577,  1.57416123,  2.03413431],
#        [-1.07949636, -1.39276269, -0.35194509],
#        [ 0.30735983, -0.30466531,  0.11132294],
#        [ 1.00195335, -0.94671035, -0.98457992],
#        [-1.41047716,  0.20897072,  0.73897639],
#        [-0.93265276, -1.13594468, -0.21246654],
#        [ 0.48683533, -0.36549063, -0.52629327],
#        [ 0.7840188 ,  0.13462867, -0.76539935],
#        [-1.50254577, -1.25083695,  0.15615533],
#        [ 1.52173306, -1.37248759, -0.23737343],
#        [-1.26013729,  1.19569258, -0.82517587],
#        [-1.61209575,  1.10107541,  1.10261689],
#        [-0.45133209, -0.58175843, -0.87498963],
#        [ 0.34465344, -0.48714127, -1.29840665],
#        [-1.56664416,  0.96590803,  0.83362255],
#        [-0.82310278, -0.79802623, -1.11907709],
#        [-0.53291186, -0.87912666, -1.23863013],
#        [ 0.97864484,  1.02673335,  2.02915294],
#        [ 0.20014069,  0.60771449,  1.21718855],
#        [ 0.92853155, -0.97374382,  1.39651811],
#        [ 0.5998816 , -1.29138716, -1.12405846],
#        [-0.89885543, -0.89940177, -1.3731273 ],
#        [ 0.52412895,  0.41172179, -0.51134914],
#        [ 1.71868995,  0.3441381 , -1.32829491],
#        [ 0.61736298,  0.5401308 ,  0.50983307],
#        [ 0.62552095, -1.31842064,  0.30559663],
#        [-0.92332936, -0.73720091,  0.41518691],
#        [-0.81377938,  0.33062136, -0.62093943],
#        [-0.5667092 , -1.01429404, -1.05930057],
#        [-0.29283424, -0.96022709,  1.00797073],
#        [-0.97693893, -0.6763756 , -0.50636776],
#        [-0.07723054, -1.38600432, -0.0929135 ],
#        [ 0.48566991, -0.10191424, -0.94472891],
#        [ 1.06372089, -1.18325326, -0.24733618],
#        [ 0.57424224,  1.69581187,  1.21718855],
#        [-0.3511055 , -1.00753567, -0.26726168],
#        [-1.41164259, -0.7845095 ,  0.06150917],
#        [ 0.42506779,  1.59443634,  1.50610839],
#        [ 1.56252295, -0.84533482, -0.35194509],
#        [-0.29866136,  0.39820505, -0.7106042 ],
#        [ 0.0626205 ,  1.26327626,  1.49614564],
#        [-0.23805924,  0.96590803,  2.5272906 ],
#        [ 1.60214741,  1.31058485,  1.87971164],
#        [ 1.38770914, -1.33193737,  0.72403226],
#        [-1.03287934,  0.68881491, -0.24733618],
#        [ 0.82364327,  1.43899385, -0.06302524],
#        [ 0.54860288, -0.2843902 ,  1.85480476],
#        [-0.2683603 ,  0.81046555, -0.80026898],
#        [-1.65521649, -0.74395928, -1.13402122],
#        [ 0.2141258 , -0.11543098,  0.94321283],
#        [-0.60866451,  1.41196038,  1.09763551],
#        [ 0.83413209,  0.73612349,  1.52105252],
#        [-1.47457556, -0.16949793, -0.57112566],
#        [ 0.79916933,  0.09407845, -1.21870462],
#        [-1.48389896, -0.06136403,  1.09265413],
#        [ 1.07304429,  0.79019044, -1.15394672],
#        [ 1.40752138,  1.43223548, -1.16889085],
#        [ 0.75371774,  1.82422088,  0.4600193 ],
#        [-1.33588994,  0.13462867, -1.3083694 ],
#        [-1.18438464,  1.12810889,  0.82864117],
#        [ 0.90755389, -1.36572922, -0.64086493],
#        [ 0.49266246, -0.30466531, -0.14272727],
#        [ 0.70826615, -0.96022709, -0.10287626],
#        [-0.6494544 , -1.50765496, -0.26228031],
#        [-1.27295697,  1.0808003 ,  1.84982338],
#        [ 0.25957739, -1.04808588, -0.78034348],
#        [-0.89652458, -0.14246446, -0.50636776],
#        [ 0.95417091,  1.01997499,  0.17608083],
#        [-1.14009848,  1.64850329, -0.99454267],
#        [ 1.35857351,  0.41848016, -0.6259208 ],
#        [ 0.04280827, -1.44007127, -0.20748517],
#        [-1.69484095,  1.14838399, -0.98457992],
#        [ 1.68489261, -1.25083695, -0.99454267],
#        [-0.88020862, -0.44659105,  0.61444198],
#        [-0.08072682, -0.56148332, -0.14272727],
#        [ 0.29337472,  1.15514236,  0.4600193 ],
#        [-0.57020547, -1.42655454,  0.0764533 ],
#        [-1.49438779,  1.01321662, -0.34198233],
#        [-1.00840541, -0.71692581,  0.72901364],
#        [ 1.64876443,  1.37816853,  2.15866873],
#        [ 1.39237085, -0.1762563 , -1.40301555],
#        [-0.58185973, -0.52769148,  0.51979582],
#        [ 1.61030539, -0.81154297, -1.09915158],
#        [-1.18205379,  0.21572909, -0.3917961 ],
#        [ 1.71053197,  0.38468831,  0.73399502],
#        [ 0.88890709, -1.23732021,  1.06276587],
#        [-0.90584798,  1.47954407,  0.35541039],
#        [-0.81261395,  0.27655441, -0.3071127 ],
#        [-0.81261395, -1.47386312, -0.68071594],
#        [ 1.56835008, -0.5885168 ,  0.42514967],
#        [ 0.24093058,  1.31058485, -1.23863013],
#        [-0.19493851, -1.14270305,  0.1412112 ],
#        [-1.64006596,  0.49282222, -0.94971028],
#        [-0.03760608,  0.452272  , -0.79030623],
#        [ 0.70710073, -1.17649489, -0.45157262],
#        [-0.82543363, -0.15598119,  0.20098772],
#        [ 1.63011762, -0.5885168 , -1.23364875],
#        [ 1.19191768,  0.51309732, -0.40674023],
#        [-1.24265591,  1.24975953, -1.12903984],
#        [ 0.65698744, -0.02081382,  0.15615533],
#        [ 0.75255232,  0.46578874, -0.95469166],
#        [ 0.866764  ,  0.71584839,  0.46998206],
#        [-0.42336188,  1.70257024,  1.1424679 ],
#        [-0.42336188, -0.56148332,  0.1611367 ],
#        [-0.67392833,  0.19545399,  2.23837076],
#        [-0.83242618,  1.81070414,  0.85852943],
#        [-1.54916278, -0.45334942,  1.05280312],
#        [ 0.62552095, -1.35221248, -0.36190784],
#        [-0.09587735,  1.60795308,  1.52105252],
#        [ 1.06372089,  0.33062136, -0.87000826],
#        [ 0.04164284,  0.87804924, -1.11907709],
#        [-1.47690641, -0.44659105, -0.3071127 ],
#        [ 0.9448475 , -0.46010779,  1.06774725],
#        [ 0.88890709, -1.29814553, -0.76539935]])

# %%
x_test
# Out:
# array([[ 0.01367264,  0.08732008, -0.46651675],
#        [-1.12028625, -0.74395928, -0.50138639],
#        [-0.17512627,  1.3646518 ,  0.02165816],
#        [ 0.28055504, -1.0007773 ,  0.33548489],
#        [-1.39066493,  0.70233165, -0.456554  ],
#        [-0.41287305,  1.21596768,  1.73027034],
#        [-1.60160692,  1.7769123 ,  2.31807278],
#        [-0.05625289,  0.28331278,  0.88343631],
#        [-1.42562769,  0.8442574 ,  1.86476751],
#        [ 0.5998816 ,  0.04676987, -0.7106042 ],
#        [ 1.34225755,  1.35789343,  1.30685333],
#        [-1.38250696, -1.41979617, -0.38681472],
#        [ 1.02992356, -1.29814553,  2.80624769],
#        [ 0.45187257, -0.10867261, -0.32205683],
#        [-0.82776448,  0.83749903,  1.2072258 ],
#        [-0.30215764, -0.20328978, -0.84012   ],
#        [-0.58768685, -1.43331291, -1.04933781],
#        [-1.40465004,  1.10783378, -0.95469166],
#        [-1.2007006 ,  0.27655441,  0.33050351],
#        [ 0.80732731,  0.06704498,  1.45131325],
#        [ 1.11383418,  1.04025009, -0.26228031],
#        [-0.06790714, -1.39952106, -0.96963579],
#        [-0.65761238, -0.85885155,  0.36039177],
#        [-0.16813372, -0.2843902 ,  0.30559663],
#        [-0.84757671, -0.37900737, -0.7753621 ],
#        [ 0.73973264, -0.13570609, -0.88495239],
#        [ 0.22694548, -0.85209319, -0.5412374 ],
#        [ 0.68612307,  1.52009428, -0.44160987],
#        [ 1.22105332,  0.93887456,  2.18357561],
#        [ 0.33766089, -0.00729708,  0.15117395],
#        [ 1.57650805,  1.14838399,  1.36164847],
#        [ 1.4867703 ,  0.42523853,  1.55592216],
#        [-1.20186602,  0.22248746, -0.39677748],
#        [ 1.67323836,  1.33085995,  1.13250515],
#        [ 0.95766718, -0.38576573, -0.11283901],
#        [-0.60516823, -1.19677   , -1.01446818],
#        [ 0.86443315,  1.78367067, -1.25855563],
#        [ 0.40409013, -0.79802623,  1.49116426],
#        [-0.07956139, -0.54796659, -0.90985927],
#        [-0.68674801, -0.73044255, -0.12778314],
#        [ 0.85860603,  0.73612349,  0.82864117],
#        [ 1.52406391,  1.7769123 ,  0.66425574],
#        [ 1.09518738, -0.39928247, -0.27722444],
#        [ 1.08586397, -0.4803829 , -0.05804387],
#        [ 1.13131556,  1.78367067,  0.78879016],
#        [ 0.78518423,  1.37816853,  0.26574561],
#        [-1.60277235, -1.38600432, -1.36814592],
#        [-0.483964  , -1.14270305,  0.29563387],
#        [-1.50604204,  1.42547712,  3.03539102],
#        [-1.48506439, -0.71016744, -0.25231756],
#        [-0.12734383,  1.29030974,  0.86849219],
#        [-1.61792288,  0.37117158,  0.64433024],
#        [ 1.09518738, -1.03456914, -0.98457992],
#        [-0.3371204 , -0.53444985, -1.14896535],
#        [ 1.36090436, -1.29138716, -0.44659124],
#        [-0.38723369, -0.35197389,  0.50485169],
#        [-0.79163629,  1.63498655,  0.30061525],
#        [ 0.35980397,  0.72936512,  0.50983307],
#        [-0.11568958, -0.23032325, -0.59105117],
#        [ 0.8434555 , -1.16297815, -0.05306249]])

# %% [markdown]
# # Machine Learning Techniques

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Create and train the Linear Regression Model
model_lr = LinearRegression()
model_lr.fit(x_train, y_train)

# Make predictions
y_pred_lr = model_lr.predict(x_test)

# Calculate performance metrics
mae_lr = mean_absolute_error(y_test, y_pred_lr)
mse_lr = mean_squared_error(y_test, y_pred_lr)
rmse_lr = np.sqrt(mse_lr)
mape_lr = np.mean(np.abs((y_test - y_pred_lr) / np.abs(y_test)))
accuracy_lr = 100 * (1 - mape_lr)

# Print the performance metrics for Linear Regression
print('Linear Regression Metrics:')
print('Mean Absolute Error (MAE):', mae_lr)
print('Mean Squared Error (MSE):', mse_lr)
print('Root Mean Squared Error (RMSE):', rmse_lr)
print('Accuracy:', round(accuracy_lr, 2))
print('Mean Absolute Percentage Error (MAPE):', round(mape_lr * 100, 2))
# Out:
# Linear Regression Metrics:
# Mean Absolute Error (MAE): 1.1891174154910273
# Mean Squared Error (MSE): 2.5245302415840842
# Root Mean Squared Error (RMSE): 1.5888770379057293
# Accuracy: 91.39
# Mean Absolute Percentage Error (MAPE): 8.61

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.tree import DecisionTreeRegressor

# Create and train the DecisionTree
model = DecisionTreeRegressor()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mape = np.mean(np.abs((y_test - y_pred) / np.abs(y_test)))
accuracy = 100 * (1 - mape)

# Print the performance metrics
print('Mean Absolute Error (MAE):', mae)
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('Mean absolute Percentage Error (MAPE):', round(mape * 100, 2))
print('Accuracy:', round(accuracy, 2))
# Out:
# Mean Absolute Error (MAE): 1.0133333333333334
# Mean Squared Error (MSE): 2.258666666666667
# Root Mean Squared Error (RMSE): 1.5028861123407413
# Mean absolute Percentage Error (MAPE): 7.83
# Accuracy: 92.17

# %%
from sklearn.ensemble import RandomForestRegressor

# Create and train the Rondom Forest model
model_rf = RandomForestRegressor(n_estimators=100, random_state=42)
model_rf.fit(x_train, y_train)

# Make predictions
y_pred_rf = model_rf.predict(x_test)

#Calculote performance metrics
mae_rf = mean_absolute_error(y_test, y_pred_rf)
mse_rf = mean_squared_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mse_rf)
mape_rf = np.mean(np.abs((y_test - y_pred_rf) / np.abs(y_test)))
accuracy_rf = 100 * (1 - mape_rf)

#Print the performance metrics for Random Forest
print('Random Forest Metrics:')
print('Mean Absolute Error (MAE):', mae_rf)
print('Mean Squared Error (MSE):', mse_rf)
print('Root Mean Squared Error (RMSE):', rmse_rf)
print('Mean Absolute Percentage Error (MAPE):', round(mape_rf * 100, 2))
print('Accuracy:', round(accuracy_rf, 2))
# Out:
# Random Forest Metrics:
# Mean Absolute Error (MAE): 0.9359499999999983
# Mean Squared Error (MSE): 1.3268911166666646
# Root Mean Squared Error (RMSE): 1.1519075990142025
# Mean Absolute Percentage Error (MAPE): 6.6
# Accuracy: 93.4

# %%
pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.1.3-py3-none-win_amd64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in c:\users\panku\anaconda3\lib\site-packages (from xgboost) (2.3.5)
# Requirement already satisfied: scipy in c:\users\panku\anaconda3\lib\site-packages (from xgboost) (1.16.3)
# Downloading xgboost-3.1.3-py3-none-win_amd64.whl (72.0 MB)
#    ---------------------------------------- 0.0/72.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/72.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/72.0 MB ? eta -:--:--
#    - -------------------------------------- 2.9/72.0 MB 9.0 MB/s eta 0:00:08
#    --- ------------------------------------ 7.1/72.0 MB 13.7 MB/s eta 0:00:05
#    ------ --------------------------------- 11.8/72.0 MB 16.2 MB/s eta 0:00:04
#    --------- ------------------------------ 17.8/72.0 MB 18.9 MB/s eta 0:00:03
#    ------------- -------------------------- 24.1/72.0 MB 21.0 MB/s eta 0:00:03
#    ---------------- ----------------------- 30.4/72.0 MB 22.2 MB/s eta 0:00:02
#    --------------------- ------------------ 38.0/72.0 MB 24.0 MB/s eta 0:00:02
#    ------------------------- -------------- 45.6/72.0 MB 25.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 52.4/72.0 MB 26.1 MB/s eta 0:00:01
#    --------------------------------- ------ 60.0/72.0 MB 27.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 63.7/72.0 MB 26.2 MB/s eta 0:00:01
#    -------------------------------------- - 69.5/72.0 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  71.8/72.0 MB 26.4 MB/s eta 0:00:01
#    ---------------------------------------- 72.0/72.0 MB 25.0 MB/s  0:00:03
# Installing collected packages: xgboost
# Successfully installed xgboost-3.1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost as xgb

# Create and train the XGBoost model 
model_xgb = xgb.XGBRegressor()  
model_xgb.fit(x_train, y_train)
# Make predictions
y_pred_xgb = model_xgb.predict(x_test)

# Calculate performance metrics
mae_xgb = mean_absolute_error(y_test, y_pred_xgb)  
mse_xgb = mean_squared_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(mse_xgb)
mape_xgb = np.mean(np.abs((y_test - y_pred_xgb) / np.abs(y_test)))  
accuracy_xgb = 100 * (1 - mape_xgb)  

# Print the performance metrics for XGBoost
print('XGBoost Metrics:')
print('Mean Absolute Error (MAE):', mae_xgb)
print('Mean Squared Error (MSE):', mse_xgb)
print('Root Mean Squared Error (RMSE):', rmse_xgb)  
print('Mean Absolute Percentage Error (MAPE):', round(mape_xgb *100, 2)) 
print('Accuracy:', round(accuracy_xgb, 2))
# Out:
# XGBoost Metrics:
# Mean Absolute Error (MAE): 0.8681395928064982
# Mean Squared Error (MSE): 1.3746027420341036
# Root Mean Squared Error (RMSE): 1.1724345363533537
# Mean Absolute Percentage Error (MAPE): 6.1
# Accuracy: 93.9

# %% [markdown]
# # Cross-validation for our model

# %%
# Cross validation for our model
from sklearn.model_selection import ShuffleSplit, cross_val_score
model=LinearRegression()
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print("\nMean Cross-validation Accuracy :" ,np.mean(results))
# Out:
# [0.85098858 0.91453109 0.93379397 0.87740922 0.85988213 0.86571358
#  0.90955073 0.89110188 0.85752129 0.90191953]
#
# Mean Cross-validation Accuracy : 0.8862411992827102

# %%
# Cross validation for our model
model=DecisionTreeRegressor(max_depth=3)
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print("\nMean Cross-validation Accuracy :" ,np.mean(results))
# Out:
# [0.89005772 0.901299   0.84382778 0.86553863 0.84398378 0.86982004
#  0.90058086 0.8980732  0.85118689 0.88153329]
#
# Mean Cross-validation Accuracy : 0.8745901189141911

# %%
# Cross validation for our model
model=RandomForestRegressor(random_state=5)
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print("\nMean Cross-validation Accuracy:",np.mean(results))
# Out:
# [0.94169911 0.9430492  0.94464721 0.95370564 0.94732642 0.93239434
#  0.9275394  0.90923959 0.95090379 0.93858399]
#
# Mean Cross-validation Accuracy: 0.9389088704905155

# %%
model_xgb = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)

# Define ShuffleSplit cross-validation
ssplit = ShuffleSplit(n_splits=10, test_size=0.3)

# Perform cross-validation
results_xgb = cross_val_score(model_xgb, x, y, cv=ssplit)

# Print results for each fold
print("Cross-validation results for each fold:")
print(results_xgb)

# Print mean accuracy across all folds
print("\nMean Cross-validation Accuracy:", np.mean(results_xgb))
# Out:
# Cross-validation results for each fold:
# [0.93831285 0.94015292 0.94925321 0.94796188 0.95105144 0.87020494
#  0.94202783 0.91834714 0.9507508  0.94715839]
#
# Mean Cross-validation Accuracy: 0.9355221404248997

# %%
import pickle
from xgboost import XGBRegressor


model_xgb = XGBRegressor()
model_xgb.fit(x_train, y_train)

# Save the trained model to a file using pickle
with open('hr.pkl', 'wb') as file:
    pickle.dump(model_xgb, file)

print("Model saved successfully.")
# Out:
# Model saved successfully.

# %%
with open('schr.pkl', 'wb') as scaler_file:
    pickle.dump(sc, scaler_file)
